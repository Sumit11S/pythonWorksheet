# %%
import pandas as pd
titanic_df = pd.read_csv("/content/drive/MyDrive/Datasets/Titanic-Dataset.csv")
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
fare_df = titanic_df[["Fare"]]
fare_df.head()
# Out:
#       Fare
# 0   7.2500
# 1  71.2833
# 2   7.9250
# 3  53.1000
# 4   8.0500

# %%
class_age = titanic_df[["Pclass", "Age"]]
class_age.head()
# Out:
#    Pclass   Age
# 0       3  22.0
# 1       1  38.0
# 2       3  26.0
# 3       1  35.0
# 4       3  35.0

# %%
survived_gender = titanic_df[["Survived", "Sex"]]
survived_gender.head()
# Out:
#    Survived     Sex
# 0         0    male
# 1         1  female
# 2         1  female
# 3         1  female
# 4         0    male

# %%
fare_gt_100 = titanic_df[titanic_df["Fare"]>100]
print(fare_gt_100["Fare"])
# Out:
# 27     263.0000
# 31     146.5208
# 88     263.0000
# 118    247.5208
# 195    146.5208
# 215    113.2750
# 258    512.3292
# 268    153.4625
# 269    135.6333
# 297    151.5500
# 299    247.5208
# 305    151.5500
# 306    110.8833
# 307    108.9000
# 311    262.3750
# 318    164.8667
# 319    134.5000
# 325    135.6333
# 332    153.4625
# 334    133.6500
# 337    134.5000
# 341    263.0000
# 373    135.6333
# 377    211.5000
# 380    227.5250
# 390    120.0000
# 393    113.2750
# 435    120.0000
# 438    263.0000
# 498    151.5500
# 505    108.9000
# 527    221.7792
# 537    106.4250
# 544    106.4250
# 550    110.8833
# 557    227.5250
# 581    110.8833
# 609    153.4625
# 659    113.2750
# 660    133.6500
# 679    512.3292
# 689    211.3375
# 698    110.8833
# 700    227.5250
# 708    151.5500
# 716    227.5250
# 730    211.3375
# 737    512.3292
# 742    262.3750
# 763    120.0000
# 779    211.3375
# 802    120.0000
# 856    164.8667
# Name: Fare, dtype: float64

# %% [markdown]
# 2. Filter the Titanic dataset for cases where the passenger’s class (Pclass) is 1, assigning it to
# first class.View the printed result.

# %%
# Filter the dataset where Pclass is 1
first_class = titanic_df[titanic_df['Pclass'] == 1]

# View the printed result
print(first_class)
# Out:
#      PassengerId  Survived  Pclass  \
# 1              2         1       1
# 3              4         1       1
# 6              7         0       1
# 11            12         1       1
# 23            24         1       1
# ..           ...       ...     ...
# 871          872         1       1
# 872          873         0       1
# 879          880         1       1
# 887          888         1       1
# 889          890         1       1
#
#                                                   Name     Sex   Age  SibSp  \
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                              McCarthy, Mr. Timothy J    male  54.0      0
# 11                            Bonnell, Miss. Elizabeth  female  58.0      0
# 23                        Sloper, Mr. William Thompson    male  28.0      0
# ..                                                 ...     ...   ...    ...
# 871   Beckwith, Mrs. Richard Leonard (Sallie Monypeny)  female  47.0      1
# 872                           Carlsson, Mr. Frans Olof    male  33.0      0
# 879      Potter, Mrs. Thomas Jr (Lily Alexenia Wilson)  female  56.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
#
#      Parch    Ticket     Fare        Cabin Embarked
# 1        0  PC 17599  71.2833          C85        C
# 3        0    113803  53.1000         C123        S
# 6        0     17463  51.8625          E46        S
# 11       0    113783  26.5500         C103        S
# 23       0    113788  35.5000           A6        S
# ..     ...       ...      ...          ...      ...
# 871      1     11751  52.5542          D35        S
# 872      0       695   5.0000  B51 B53 B55        S
# 879      1     11767  83.1583          C50        C
# 887      0    112053  30.0000          B42        S
# 889      0    111369  30.0000         C148        C
#
# [216 rows x 12 columns]

# %% [markdown]
# 3. Filter the Titanic dataset for cases where the passenger’s age is less than 18 and the passenger
# is female (Sex is "female"), assigning it to female under 18. View the printed result.

# %%
# Filter the dataset where Age is less than 18 and Sex is "female"
female_under_18 = titanic_df[(titanic_df['Age'] < 18) & (titanic_df['Sex'] == 'female')]

# View the printed result
print(female_under_18.head())
# Out:
#     PassengerId  Survived  Pclass                                  Name  \
# 9            10         1       2   Nasser, Mrs. Nicholas (Adele Achem)
# 10           11         1       3       Sandstrom, Miss. Marguerite Rut
# 14           15         0       3  Vestrom, Miss. Hulda Amanda Adolfina
# 22           23         1       3           McGowan, Miss. Anna "Annie"
# 24           25         0       3         Palsson, Miss. Torborg Danira
#
#        Sex   Age  SibSp  Parch   Ticket     Fare Cabin Embarked
# 9   female  14.0      1      0   237736  30.0708   NaN        C
# 10  female   4.0      1      1  PP 9549  16.7000    G6        S
# 14  female  14.0      0      0   350406   7.8542   NaN        S
# 22  female  15.0      0      0   330923   8.0292   NaN        Q
# 24  female   8.0      3      1   349909  21.0750   NaN        S

# %% [markdown]
# **Subsetting Rows by Categorical variables:**
# 1. Filter the Titanic dataset for passengers whose Embarked port is either "C" (Cherbourg) or "S"
# (Southampton), assigning the result to embarked c or s. View the printed result.

# %%
# Filter the dataset where Embarked is either "C" or "S"
embarked_c_or_s = titanic_df[titanic_df['Embarked'].isin(['C', 'S'])]

# View the printed result
print(embarked_c_or_s.head())
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %% [markdown]
# 2. Filter the Titanic dataset for passengers whose Pclass is in the list [1, 2] (indicating first
# or second class), assigning the result to first second class.View the printed result.

# %%
# Filter the dataset where Pclass is either 1 or 2
first_second_class = titanic_df[titanic_df['Pclass'].isin([1, 2])]

# View the printed result
print(first_second_class.head())
# Out:
#     PassengerId  Survived  Pclass  \
# 1             2         1       1
# 3             4         1       1
# 6             7         0       1
# 9            10         1       2
# 11           12         1       1
#
#                                                  Name     Sex   Age  SibSp  \
# 1   Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 3        Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 6                             McCarthy, Mr. Timothy J    male  54.0      0
# 9                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.0      1
# 11                           Bonnell, Miss. Elizabeth  female  58.0      0
#
#     Parch    Ticket     Fare Cabin Embarked
# 1       0  PC 17599  71.2833   C85        C
# 3       0    113803  53.1000  C123        S
# 6       0     17463  51.8625   E46        S
# 9       0    237736  30.0708   NaN        C
# 11      0    113783  26.5500  C103        S

# %% [markdown]
# **Which passenger had the highest fare paid relative to their age?**
#
# To answer the question perform following operations:
# 1. Add a column to the Titanic dataset, fare per year, containing the fare divided by the age of
# the passenger(i.e., Fare/Age).

# %%
# Add the fare_per_year column
titanic_df['fare_per_year'] = titanic_df['Fare'] / titanic_df['Age']
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# 3      0            113803  53.1000  C123        S       1.517143
# 4      0            373450   8.0500   NaN        S       0.230000

# %% [markdown]
# 2. Subset rows where fare per year is higher than 5, assigning this to high fare age.

# %%
# Subset rows where fare_per_year is higher than 5
high_fare_age = titanic_df[titanic_df['fare_per_year'] > 5]
high_fare_age.head()
# Out:
#     PassengerId  Survived  Pclass                                      Name  \
# 7             8         0       3            Palsson, Master. Gosta Leonard
# 16           17         0       3                      Rice, Master. Eugene
# 27           28         0       1            Fortune, Mr. Charles Alexander
# 43           44         1       2  Laroche, Miss. Simonne Marie Anne Andree
# 50           51         0       3                Panula, Master. Juha Niilo
#
#        Sex   Age  SibSp  Parch         Ticket      Fare        Cabin Embarked  \
# 7     male   2.0      3      1         349909   21.0750          NaN        S
# 16    male   2.0      4      1         382652   29.1250          NaN        Q
# 27    male  19.0      3      2          19950  263.0000  C23 C25 C27        S
# 43  female   3.0      1      2  SC/Paris 2123   41.5792          NaN        C
# 50    male   7.0      4      1        3101295   39.6875          NaN        S
#
#     fare_per_year
# 7       10.537500
# 16      14.562500
# 27      13.842105
# 43      13.859733
# 50       5.669643

# %% [markdown]
# 3. Sort high fare age by descending fare per year, assigning this to high fare age srt.

# %%
# Sort high_fare_age by descending fare_per_year
high_fare_age_srt = high_fare_age.sort_values(by='fare_per_year', ascending=False)
high_fare_age_srt.head()
# Out:
#      PassengerId  Survived  Pclass                             Name     Sex  \
# 305          306         1       1   Allison, Master. Hudson Trevor    male
# 297          298         0       1     Allison, Miss. Helen Loraine  female
# 386          387         0       3  Goodwin, Master. Sidney Leonard    male
# 164          165         0       3     Panula, Master. Eino Viljami    male
# 183          184         1       2        Becker, Master. Richard F    male
#
#       Age  SibSp  Parch   Ticket      Fare    Cabin Embarked  fare_per_year
# 305  0.92      1      2   113781  151.5500  C22 C26        S     164.728261
# 297  2.00      1      2   113781  151.5500  C22 C26        S      75.775000
# 386  1.00      5      2  CA 2144   46.9000      NaN        S      46.900000
# 164  1.00      4      1  3101295   39.6875      NaN        S      39.687500
# 183  1.00      2      1   230136   39.0000       F4        S      39.000000

# %% [markdown]
# 4. Select only the Name and fare per year columns of high fare age srt and save the result as result.

# %%
# Select only the Name and fare_per_year columns
result = high_fare_age_srt[['Name', 'fare_per_year']]
# Look at the result
print(result)
# Out:
#                                        Name  fare_per_year
# 305          Allison, Master. Hudson Trevor     164.728261
# 297            Allison, Miss. Helen Loraine      75.775000
# 386         Goodwin, Master. Sidney Leonard      46.900000
# 164            Panula, Master. Eino Viljami      39.687500
# 183               Becker, Master. Richard F      39.000000
# ..                                      ...            ...
# 318                Wick, Miss. Mary Natalie       5.318281
# 348  Coutts, Master. William Loch "William"       5.300000
# 205              Strom, Miss. Telma Matilda       5.231250
# 813      Andersson, Miss. Ebba Iris Alfrida       5.212500
# 480          Goodwin, Master. Harold Victor       5.211111
#
# [68 rows x 2 columns]

# %% [markdown]
# **Which adult male passenger (age ≥ 18 and Sex is ’male’) paid the highest fare relative to their
# class?**
#
# To answer the question perform following operations:
# 1. Add a column to the Titanic dataset, fare per class, containing the fare divided by the passenger
# class i.e. Fare / Pclass.

# %%
titanic_df['fare_per_class'] = titanic_df["Fare"] / titanic_df["Pclass"]
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year  \
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# 3      0            113803  53.1000  C123        S       1.517143
# 4      0            373450   8.0500   NaN        S       0.230000
#
#    fare_per_class
# 0        2.416667
# 1       71.283300
# 2        2.641667
# 3       53.100000
# 4        2.683333

# %% [markdown]
# 2. Subset rows where the passenger is male (Sex is ”male”) and an adult (Age is greater than or equal
# to 18), assigning this to adult males.

# %%
# Subset rows where the passenger is male and an adult
adult_males = titanic_df[(titanic_df['Sex'] == 'male') & (titanic_df['Age'] >= 18)]
adult_males.head()
# Out:
#     PassengerId  Survived  Pclass                            Name   Sex   Age  \
# 0             1         0       3         Braund, Mr. Owen Harris  male  22.0
# 4             5         0       3        Allen, Mr. William Henry  male  35.0
# 6             7         0       1         McCarthy, Mr. Timothy J  male  54.0
# 12           13         0       3  Saundercock, Mr. William Henry  male  20.0
# 13           14         0       3     Andersson, Mr. Anders Johan  male  39.0
#
#     SibSp  Parch     Ticket     Fare Cabin Embarked  fare_per_year  \
# 0       1      0  A/5 21171   7.2500   NaN        S       0.329545
# 4       0      0     373450   8.0500   NaN        S       0.230000
# 6       0      0      17463  51.8625   E46        S       0.960417
# 12      0      0  A/5. 2151   8.0500   NaN        S       0.402500
# 13      1      5     347082  31.2750   NaN        S       0.801923
#
#     fare_per_class
# 0         2.416667
# 4         2.683333
# 6        51.862500
# 12        2.683333
# 13       10.425000

# %% [markdown]
# Sort adult males by descending fare per class, assigning this to adult males srt.

# %%
# Sort adult_males by descending fare_per_class
adult_males_srt = adult_males.sort_values(by='fare_per_class', ascending=False)
adult_males_srt.head()
# Out:
#      PassengerId  Survived  Pclass                                Name   Sex  \
# 737          738         1       1              Lesurer, Mr. Gustave J  male
# 679          680         1       1  Cardeza, Mr. Thomas Drake Martinez  male
# 27            28         0       1      Fortune, Mr. Charles Alexander  male
# 438          439         0       1                   Fortune, Mr. Mark  male
# 118          119         0       1            Baxter, Mr. Quigg Edmond  male
#
#       Age  SibSp  Parch    Ticket      Fare        Cabin Embarked  \
# 737  35.0      0      0  PC 17755  512.3292         B101        C
# 679  36.0      0      1  PC 17755  512.3292  B51 B53 B55        C
# 27   19.0      3      2     19950  263.0000  C23 C25 C27        S
# 438  64.0      1      4     19950  263.0000  C23 C25 C27        S
# 118  24.0      0      1  PC 17558  247.5208      B58 B60        C
#
#      fare_per_year  fare_per_class
# 737      14.637977        512.3292
# 679      14.231367        512.3292
# 27       13.842105        263.0000
# 438       4.109375        263.0000
# 118      10.313367        247.5208

# %%
# Select only the Name, Age, and fare_per_class columns
result = adult_males_srt[['Name', 'Age', 'fare_per_class']]
result.head()
# Out:
#                                    Name   Age  fare_per_class
# 737              Lesurer, Mr. Gustave J  35.0        512.3292
# 679  Cardeza, Mr. Thomas Drake Martinez  36.0        512.3292
# 27       Fortune, Mr. Charles Alexander  19.0        263.0000
# 438                   Fortune, Mr. Mark  64.0        263.0000
# 118            Baxter, Mr. Quigg Edmond  24.0        247.5208

# %% [markdown]
# **Exploratory Data Analysis with Group-by Method Practice Exercise:**
#
# Based on the dataset Answer the following question:
#
# What percent of the total fare revenue came from each passenger class?
# To answer the question perform following operation:
# 1. Calculate the total Fare paid across all passengers in the Titanic dataset.

# %%
# Calculate the total Fare paid across all passengers
total_fare = titanic_df['Fare'].sum()
print(total_fare)
# Out:
# 28693.9493

# %%
# Subset for passengers in first class
first_class = titanic_df[titanic_df['Pclass'] == 1]
# Calculate the total fare for first class passengers
first_class_total_fare = first_class['Fare'].sum()
print("The sum of first class fare is",first_class_total_fare)

# Subset for passengers in second class
second_class = titanic_df[titanic_df['Pclass'] == 2]
# Calculate the total fare for second class passengers
second_class_total_fare = second_class['Fare'].sum()
print("The sum of second class fare is ",second_class_total_fare)

# Subset for passengers in third class
third_class = titanic_df[titanic_df['Pclass'] == 3]
# Calculate the total fare for third class passengers
third_class_total_fare = third_class['Fare'].sum()
print("The sum of third class fare is ",third_class_total_fare)

fare_totals = [first_class_total_fare, second_class_total_fare, third_class_total_fare]
# Out:
# The sum of first class fare is 18177.4125
# The sum of second class fare is  3801.8417
# The sum of third class fare is  6714.6951

# %% [markdown]
# What percent of the total number of passengers on the Titanic belonged to each age group
# (e.g., child, adult, senior)?
#
# To answer the question perform following operation:
# 1. Create a new column, age group, that categorizes passengers into "child" (age < 18), "adult" (age
# 18{64), and "senior" (age 65 and above).

# %%
def age_group(age):
  if age < 18:
    return "child"
  elif age >= 18 and age < 64:
    return "adult"
  else:
    return "senior"

titanic_df['age_group'] = titanic_df['Age'].apply(age_group)
titanic_df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked  fare_per_year  \
# 0      0         A/5 21171   7.2500   NaN        S       0.329545
# 1      0          PC 17599  71.2833   C85        C       1.875876
# 2      0  STON/O2. 3101282   7.9250   NaN        S       0.304808
# 3      0            113803  53.1000  C123        S       1.517143
# 4      0            373450   8.0500   NaN        S       0.230000
#
#    fare_per_class age_group
# 0        2.416667     adult
# 1       71.283300     adult
# 2        2.641667     adult
# 3       53.100000     adult
# 4        2.683333     adult

# %% [markdown]
# 2. Calculate the total number of passengers on the Titanic.

# %%
# Calculate the total number of passengers
total_passengers = len(titanic_df)
print("Total number of passengers:", total_passengers)
# Out:
# Total number of passengers: 891

# %% [markdown]
# 4. Divide the count of each age group by the total number of passengers to get the proportion of passengers
# in each age group.

# %%
# Calculate the counts for each age group
age_group_counts = titanic_df['age_group'].value_counts()
print(age_group_counts)

# Calculate the proportions for each age group
age_group_proportions = age_group_counts / total_passengers
print(age_group_proportions)
# Out:
# age_group
# adult     588
# senior    190
# child     113
# Name: count, dtype: int64
# age_group
# adult     0.659933
# senior    0.213244
# child     0.126824
# Name: count, dtype: float64

# %% [markdown]
# 5. Display the proportion as a percentage.

# %%
# Convert proportions to percentages
age_group_percentages = age_group_proportions * 100
print(age_group_percentages)
# Out:
# age_group
# adult     65.993266
# senior    21.324355
# child     12.682379
# Name: count, dtype: float64
